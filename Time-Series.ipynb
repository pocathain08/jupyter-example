# %% [markdown]
# # Time Series
# - Ref: https://docs.python.org/3/library/datetime.html
# - Ref: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html
# - Ref: https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.random.poisson.html
# - Time series is a sequence of observations recorded at regular time intervals.
# - A computer will view a given point in time as a number that gets bigger as we move away from time zero (1 Jan 1970).

# %%
import pandas as pd

# %%
df= pd.read_csv("http://cli.met.ie/cli/climate_data/webdata/hly4935.csv", skiprows=23, low_memory=False, nrows=1000)

# %%
df['datetime'] = pd.to_datetime(df['date'])
# Convet to a date time using to_datetime.
# datetime useful as an index
# This adds a new col created from the original col but not in the correct format for pandas.
# Therefore, the col is converted to a date time format that can be used

# %%
df
# Out:
#                   date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0    10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0
# 1    31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0
# 2    31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0
# 3    31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0
# 4    31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0
# ..                 ...  ...  ...    ...   ...    ...   ...    ...    ...
# 995  10-sep-1996 18:00    0  0.0      0  13.7      0  12.3   11.1   13.2
# 996  10-sep-1996 19:00    0  0.0      0  12.8      0  12.0   11.3   13.4
# 997  10-sep-1996 20:00    0  0.0      0  12.4      0  11.7   11.1   13.2
# 998  10-sep-1996 21:00    0  0.0      0  12.2      0  11.6   11.1   13.2
# 999  10-sep-1996 22:00    0  0.0      0  12.0      0  11.4   10.9   13.0
#
#      rhum  ... wdsp  ind.4 wddir  ww   w  sun    vis  clht clamt  \
# ...

# %%
import seaborn as sns

# %%
sns.lineplot(x = "datetime", y="temp", data=df[1:])
# df[1:] starts from indexed by 1 rather that the one starting with 0
# Out:
# C:\Users\35386\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
